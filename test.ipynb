# %% [markdown]
# Test the Jupyter code

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generar datos aleatorios
np.random.seed(42)  # Semilla para reproducibilidad
data_size = 100

# Datos simulados: dos columnas de valores aleatorios
x_values = np.linspace(0, 10, data_size)
y_values = 3 * x_values + 7 + np.random.normal(0, 3, data_size)  # Añadimos ruido gaussiano

# Crear un DataFrame
data = pd.DataFrame({
    "X": x_values,
    "Y": y_values
})

# Mostrar las primeras filas del DataFrame
print("\nPrimeras filas del DataFrame:")
print(data.head())

# Mostrar estadísticas descriptivas
print("\nEstadísticas descriptivas del DataFrame:")
print(data.describe())

# Crear una gráfica
plt.figure(figsize=(10, 6))

# Gráfico de dispersión
plt.scatter(data["X"], data["Y"], color='skyblue', label="Datos Aleatorios", alpha=0.7)

# Línea de tendencia ideal
plt.plot(data["X"], 3 * data["X"] + 7, color='orange', label="Tendencia Ideal", linestyle='--')

# Añadir línea de regresión ajustada
coeffs = np.polyfit(data["X"], data["Y"], 1)
polynomial = np.poly1d(coeffs)
plt.plot(data["X"], polynomial(data["X"]), color='green', label="Regresión Ajustada", linewidth=2)

# Personalizar la gráfica
plt.title("Gráfico de Datos Aleatorios con Regresión Ideal y Ajustada")
plt.xlabel("Valores X")
plt.ylabel("Valores Y")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

# Mostrar la gráfica
plt.tight_layout()
plt.show()
# Out:
# Primeras filas del DataFrame:
#          X          Y
# 0  0.00000   8.490142
# 1  0.10101   6.888237
# 2  0.20202   9.549126
# 3  0.30303  12.478180
# 4  0.40404   7.509661
#
# Estadísticas descriptivas del DataFrame:
#                 X           Y
# count  100.000000  100.000000
# mean     5.000000   21.688460
# std      2.930454    9.318963
# min      0.000000    5.199553
# 25%      2.500000   13.651154
# 50%      5.000000   21.508526
# 75%      7.500000   30.296990
# max     10.000000   37.481693
